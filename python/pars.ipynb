# %% [markdown]
# # Figure 2: Empirical estimates of mutational parameters
#
# Generate summary statistics and **figures/pars.pdf**.

# %%
from doomed import *
import pandas as pd
# Out:
# /Users/rbazev/Documents/GitHub/doomed/python/doomed.py:34: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   rcParams['text.latex.preamble'] = [r'\usepackage{sansmath}', r'\sansmath']

# %%
from matplotlib import rcParams
rcParams['text.usetex'] = True
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = 'Helvetica'
rcParams['text.latex.preamble'] = [r'\usepackage{sansmath}', r'\sansmath']
# Out:
# /Users/rbazev/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   """

# %%
data = pd.read_csv('../data/pars.csv', encoding = "ISO-8859-1")
data.loc[data['hom'],'s'] = data['s'] / 2
del data['hom']
data = data[pd.notna(data['u'])]
print('n =', len(data), 'estimates')
data
# Out:
# n = 36 estimates
#                        species      group  mutator         u        s  \
# 0   Vesicular Stomatitis Virus      virus    False  1.160000  0.00220
# 13          phi6 bacteriophage      virus    False  0.030000  0.09300
# 14            Escherichia coli   bacteria    False  0.000170  0.01200
# 17            Escherichia coli   bacteria     True  0.005000  0.03000
# 18            Escherichia coli   bacteria    False  0.000946  0.00300
# 19            Escherichia coli   bacteria     True  0.139000  0.00320
# 20    Saccharomyces cerevisiae  eukaryote    False  0.000126  0.06100
# 21    Saccharomyces cerevisiae  eukaryote    False  0.001140  0.04300
# 22    Saccharomyces cerevisiae  eukaryote    False  0.000095  0.21700
# 23    Saccharomyces cerevisiae  eukaryote     True  0.022800  0.01500
# 24          Amsinckia gloriosa  eukaryote    False  0.198000  0.02500
# 25       Amsinckia douglasiana  eukaryote    False  0.161000  0.05150
# 26        Arabidopsis thaliana  eukaryote    False  0.100000  0.11500
# 27        Arabidopsis thaliana  eukaryote    False  0.004000  0.23000
# 28           Daphnia pulicaria  eukaryote    False  0.990000  0.10500
# 29           Daphnia pulicaria  eukaryote    False  0.015000  0.08200
# 30             Daphnia arenata  eukaryote    False  0.690000  0.03500
# 31      Caenorhabditis elegans  eukaryote    False  0.005200  0.10500
# 32      Caenorhabditis elegans  eukaryote    False  0.015000  0.10900
# 33      Caenorhabditis elegans  eukaryote    False  0.036000  0.02900
# 34     Tetrahymena thermophila  eukaryote    False  0.009400  0.05450
# 35      Caenorhabditis elegans  eukaryote    False  0.020000  0.06000
# 36         Oscheius myriophila  eukaryote    False  0.005500  0.21900
# 37      Caenorhabditis elegans  eukaryote    False  0.007450  0.15400
# 38     Caenorhabditis briggsae  eukaryote    False  0.049500  0.07500
# 39     Drosophila melanogaster  eukaryote    False  0.032000  0.05150
# 40     Drosophila melanogaster  eukaryote    False  0.022000  0.09550
# 41     Drosophila melanogaster  eukaryote    False  0.020000  0.11300
# 42     Drosophila melanogaster  eukaryote    False  0.060000  0.13250
# 43     Drosophila melanogaster  eukaryote    False  0.044000  0.08000
# 44     Drosophila melanogaster  eukaryote    False  0.011600  0.04050
# 45     Drosophila melanogaster  eukaryote    False  0.088000  0.14500
# 46     Drosophila melanogaster  eukaryote    False  0.680000  0.15000
# 47     Drosophila melanogaster  eukaryote    False  0.060260  0.05650
# 48   Chlamydomonas reinhardtii  eukaryote    False  0.000816  0.02645
# 51   Daktulosphaira vitifoliae  eukaryote    False  0.023400  0.11600
#
#         method                      source  \
# 0           BM           Elena & Moya 1999
# 13          ML            Burch et al 2007
# 14          BM         Kibota & Lynch 1996
# 17          ML         Trindade et al 2010
# 18       Novel           Robert et al 2018
# 19       Novel           Robert et al 2018
# 20          ML          Joseph & Hall 2004
# 21      Tetrad            Wloch et al 2001
# 22          ML        Zeyl & DeVisser 2001
# 23          BM        Zeyl & DeVisser 2001
# 24          ML                 Schoen 2005
# 25          ML                 Schoen 2005
# 26          BM          Schultz et al 1999
# 27          BM             Shaw et al 2000
# 28  Inbreeding           Deng & Lynch 1997
# 29          BM            Latta et al 2012
# 30  Inbreeding           Deng & Lynch 1997
# 31          ML  Keightley & Caballero 1997
# 32          ML       Vassilieva et al 2000
# 33          ML       Vassilieva et al 2000
# 34          BM             Long et al 2013
# 35          BM          Matsuba et al 2012
# 36          BM             Baer et al 2005
# 37          BM             Baer et al 2005
# 38          BM             Baer et al 2005
# 39          MD    Garcia-Dorado et al 1998
# 40          MD    Garcia-Dorado et al 1998
# 41          MD    Garcia-Dorado et al 1998
# 42          MD    Garcia-Dorado et al 1998
# 43          MD    Garcia-Dorado et al 1999
# 44          BM       Chavarrias et al 2001
# 45          BM         Fry & Heinsohn 2002
# 46          BM             Gong et al 2005
# 47          BM     Charlesworth et al 2004
# 48          BM           Morgan et al 2014
# 51          BM                 Downie 2003
#
#                                               notes
# 0                           median of 3 experiments
# 13           MLE nDEL = 56 correcting for selection
# 14                                              NaN
# 17       deficient in the mismatch repair gene mutS
# 18                                              NaN
# 19                             mutH s from Table S7
# 20                                              NaN
# 21                               effect in haploids
# 22                                excluding petites
# 23                                excluding petites
# 24                 beta = 2 flower number per plant
# 25            beta = infinity average of two traits
# 26                                    Total fitness
# 27                   median of 3 fitness components
# 28                                              NaN
# 29                          median of 3 experiments
# 30                                              NaN
# 31                                     Productivity
# 32                     Productivity, generation 214
# 33       Intrinsic rate of increase, generation 214
# 34                                  Single GE lines
# 35                              median of all lines
# 36                                              NaN
# 37                         average of 2 experiments
# 38                         average of 2 experiments
# 39          data from Fernandez & Lopez-Fanjul 1996
# 40                       data from Mukai et al 1972
# 41                           data from Ohnishi 1997
# 42                       data from Houle et al 1992
# 43                               data from Fry 1999
# 44  joint analysis  of viability in two generations
# 45                               data from Fry 2001
# 46                          median of 3 experiments
# 47                          median of 3 experiments
# 48                          median of 5 experiments
# 51    Day 29 survivorship, average of 2 generations

# %%
data['u'].median(), data['s'].median(),
# Out:
# (0.0224, 0.068)

# %%
spp = data['species'].value_counts()
print('n =', len(spp), 'species')
spp
# Out:
# n = 16 species
# Drosophila melanogaster       9
# Caenorhabditis elegans        5
# Escherichia coli              4
# Saccharomyces cerevisiae      4
# Arabidopsis thaliana          2
# Daphnia pulicaria             2
# Vesicular Stomatitis Virus    1
# phi6 bacteriophage            1
# Amsinckia gloriosa            1
# Amsinckia douglasiana         1
# Daphnia arenata               1
# Tetrahymena thermophila       1
# Oscheius myriophila           1
# Caenorhabditis briggsae       1
# Chlamydomonas reinhardtii     1
# Daktulosphaira vitifoliae     1
# Name: species, dtype: int64

# %%
grp = data['group'].value_counts()
grp
# Out:
# eukaryote    30
# bacteria      4
# virus         2
# Name: group, dtype: int64

# %%
ref = data['source'].value_counts()
print('n =', len(ref), 'studies')
ref
# Out:
# n = 26 studies
# Garcia-Dorado et al 1998      4
# Baer et al 2005               3
# Robert et al 2018             2
# Zeyl & DeVisser 2001          2
# Schoen 2005                   2
# Deng & Lynch 1997             2
# Vassilieva et al 2000         2
# Elena & Moya 1999             1
# Matsuba et al 2012            1
# Morgan et al 2014             1
# Charlesworth et al 2004       1
# Gong et al 2005               1
# Fry & Heinsohn 2002           1
# Chavarrias et al 2001         1
# Garcia-Dorado et al 1999      1
# Keightley & Caballero 1997    1
# Long et al 2013               1
# Burch et al 2007              1
# Latta et al 2012              1
# Shaw et al 2000               1
# Schultz et al 1999            1
# Wloch et al 2001              1
# Joseph & Hall 2004            1
# Trindade et al 2010           1
# Kibota & Lynch 1996           1
# Downie 2003                   1
# Name: source, dtype: int64

# %%
logu = np.log10(data['u'])
logu.min(), logu.max()
# Out:
# (-4.024108863598207, 0.06445798922691845)

# %%
logs = np.log10(data['s'])
logs.min(), logs.max()
# Out:
# (-2.657577319177794, -0.638272163982407)

# %%
mu = logu.median()
ms = logs.median()
10**mu, 10**ms
# Out:
# (0.02239642828667106, 0.06763874629234343)

# %%
ulo = 10**-2.5
uhi = 10**-.85
slo = 10**-1.6
shi = 10**-.85
tmp = data[(data['u'] < ulo)]
print('ulo =', ulo, '->', len(tmp))
tmp = data[(data['u'] > uhi)]
print('uhi =', uhi, '->', len(tmp))
tmp = data[(data['s'] < slo)]
print('slo =', slo, '->', len(tmp))
tmp = data[(data['s'] > shi)]
print('shi =', shi, '->', len(tmp))
tmp = data[(data['u'] >= ulo) & (data['u'] <= uhi) & (data['s'] >= slo) & (data['s'] <= shi)]
print(len(tmp))
# Out:
# ulo = 0.0031622776601683794 -> 6
# uhi = 0.14125375446227545 -> 6
# slo = 0.025118864315095794 -> 6
# shi = 0.14125375446227545 -> 6
# 18

# %%
tmp
# Out:
#                       species      group  mutator        u       s method  \
# 13         phi6 bacteriophage      virus    False  0.03000  0.0930     ML
# 17           Escherichia coli   bacteria     True  0.00500  0.0300     ML
# 26       Arabidopsis thaliana  eukaryote    False  0.10000  0.1150     BM
# 29          Daphnia pulicaria  eukaryote    False  0.01500  0.0820     BM
# 31     Caenorhabditis elegans  eukaryote    False  0.00520  0.1050     ML
# 32     Caenorhabditis elegans  eukaryote    False  0.01500  0.1090     ML
# 33     Caenorhabditis elegans  eukaryote    False  0.03600  0.0290     ML
# 34    Tetrahymena thermophila  eukaryote    False  0.00940  0.0545     BM
# 35     Caenorhabditis elegans  eukaryote    False  0.02000  0.0600     BM
# 38    Caenorhabditis briggsae  eukaryote    False  0.04950  0.0750     BM
# 39    Drosophila melanogaster  eukaryote    False  0.03200  0.0515     MD
# 40    Drosophila melanogaster  eukaryote    False  0.02200  0.0955     MD
# 41    Drosophila melanogaster  eukaryote    False  0.02000  0.1130     MD
# 42    Drosophila melanogaster  eukaryote    False  0.06000  0.1325     MD
# 43    Drosophila melanogaster  eukaryote    False  0.04400  0.0800     MD
# 44    Drosophila melanogaster  eukaryote    False  0.01160  0.0405     BM
# 47    Drosophila melanogaster  eukaryote    False  0.06026  0.0565     BM
# 51  Daktulosphaira vitifoliae  eukaryote    False  0.02340  0.1160     BM
#
#                         source  \
# 13            Burch et al 2007
# 17         Trindade et al 2010
# 26          Schultz et al 1999
# 29            Latta et al 2012
# 31  Keightley & Caballero 1997
# 32       Vassilieva et al 2000
# 33       Vassilieva et al 2000
# 34             Long et al 2013
# 35          Matsuba et al 2012
# 38             Baer et al 2005
# 39    Garcia-Dorado et al 1998
# 40    Garcia-Dorado et al 1998
# 41    Garcia-Dorado et al 1998
# 42    Garcia-Dorado et al 1998
# 43    Garcia-Dorado et al 1999
# 44       Chavarrias et al 2001
# 47     Charlesworth et al 2004
# 51                 Downie 2003
#
#                                               notes
# 13           MLE nDEL = 56 correcting for selection
# 17       deficient in the mismatch repair gene mutS
# 26                                    Total fitness
# 29                          median of 3 experiments
# 31                                     Productivity
# 32                     Productivity, generation 214
# 33       Intrinsic rate of increase, generation 214
# 34                                  Single GE lines
# 35                              median of all lines
# 38                         average of 2 experiments
# 39          data from Fernandez & Lopez-Fanjul 1996
# 40                       data from Mukai et al 1972
# 41                           data from Ohnishi 1997
# 42                       data from Houle et al 1992
# 43                               data from Fry 1999
# 44  joint analysis  of viability in two generations
# 47                          median of 3 experiments
# 51    Day 29 survivorship, average of 2 generations

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax.set_position([.16, .16, .83, .83])
grps = ['virus', 'bacteria', 'eukaryote']
symbs = ['o','s','v']
cols = [ora, grn, blu]
ax.plot(mu, ms, '+', ms=15, color=red, markeredgewidth=2)
for i in range(3):
    tmp = data[data['group']==grps[i]]
    ax.plot(np.log10(tmp['u']), np.log10(tmp['s']), 'o', label=grps[i], color=cols[i])
ax.plot(np.log10([ulo] * 2), np.log10([slo, shi]), '-', color=red)
ax.plot(np.log10([uhi] * 2), np.log10([slo, shi]), '-', color=red)
ax.plot(np.log10([ulo, uhi]), np.log10([slo] * 2), '-', color=red)
ax.plot(np.log10([ulo, uhi]), np.log10([shi] * 2), '-', color=red)
ax.set_xlabel('Deleterious mutation rate $(u)$')
ax.set_xlim(-4.3, .3)
ax.set_xticks([-4, -2, 0])
ax.set_xticklabels([r'$10^{-4}$', r'$10^{-2}$', 1])
ax.set_ylabel('Selection coefficient $(s)$')
ax.set_ylim(-2.8, -.5)
ax.set_yticks([-2, -1])
ax.set_yticklabels([r'$10^{-2}$', r'$10^{-1}$'])
ax.legend(fontsize=14)
plt.savefig('../figures/pars.pdf')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/90/_pclxfxx04x3n35rh86rsd6w0000gn/T/ipykernel_96203/2560316690.py in <module>
#      21 ax.set_yticklabels([r'$10^{-2}$', r'$10^{-1}$'])
#      22 ax.legend(fontsize=14)
# ---> 23 plt.savefig('../figures/pars.pdf')
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     964 def savefig(*args, **kwargs):
#     965     fig = gcf()
# --> 966     res = fig.savefig(*args, **kwargs)
#     967     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     968     return res
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3003                 patch.set_edgecolor('none')
#    3004
# -> 3005         self.canvas.print_figure(fname, **kwargs)
#    3006
#    3007         if transparent:
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2259                         orientation=orientation,
#    2260                         bbox_inches_restore=_bbox_inches_restore,
# -> 2261                         **kwargs)
#    2262             finally:
#    2263                 if bbox_inches and restore_bbox:
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1667             kwargs.pop(arg)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#    1671     return wrapper
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/backends/backend_pdf.py in print_pdf(self, filename, dpi, bbox_inches_restore, metadata)
#    2723                 RendererPdf(file, dpi, height, width),
#    2724                 bbox_inches_restore=bbox_inches_restore)
# -> 2725             self.figure.draw(renderer)
#    2726             renderer.finalize()
#    2727             if not isinstance(filename, PdfPages):
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2779             self.patch.draw(renderer)
#    2780             mimage._draw_list_compositing_images(
# -> 2781                 renderer, self, artists, self.suppressComposite)
#    2782
#    2783             for sfig in self.subfigs:
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2919             renderer.stop_rasterizing()
#    2920
# -> 2921         mimage._draw_list_compositing_images(renderer, self, artists)
#    2922
#    2923         renderer.close_group('axes')
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1136         ticks_to_draw = self._update_ticks()
#    1137         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
# -> 1138                                                                 renderer)
#    1139
#    1140         for tick in ticks_to_draw:
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1062         """Return lists of bboxes for ticks' label1's and label2's."""
#    1063         return ([tick.label1.get_window_extent(renderer)
# -> 1064                  for tick in ticks if tick.label1.get_visible()],
#    1065                 [tick.label2.get_window_extent(renderer)
#    1066                  for tick in ticks if tick.label2.get_visible()])
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/axis.py in <listcomp>(.0)
#    1062         """Return lists of bboxes for ticks' label1's and label2's."""
#    1063         return ([tick.label1.get_window_extent(renderer)
# -> 1064                  for tick in ticks if tick.label1.get_visible()],
#    1065                 [tick.label2.get_window_extent(renderer)
#    1066                  for tick in ticks if tick.label2.get_visible()])
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     901
#     902         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 903             bbox, info, descent = self._get_layout(self._renderer)
#     904             x, y = self.get_unitless_position()
#     905             x, y = self.get_transform().transform((x, y))
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     306         _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     307             "lp", self._fontproperties,
# --> 308             ismath="TeX" if self.get_usetex() else False)
#     309         min_dy = (lp_h - lp_d) * self._linespacing
#     310
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/backends/_backend_pdf_ps.py in get_text_width_height_descent(self, s, prop, ismath)
#      87             fontsize = prop.get_size_in_points()
#      88             w, h, d = texmanager.get_text_width_height_descent(
# ---> 89                 s, fontsize, renderer=self)
#      90             return w, h, d
#      91         elif ismath:
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     399             dvifile = self.make_dvi(tex, fontsize)
#     400             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
# --> 401                 page, = dvi
#     402             # A total height (including the descent) needs to be returned.
#     403             return page.width, page.height + page.descent, page.descent
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/dviread.py in __iter__(self)
#     249             integers.
#     250         """
# --> 251         while self._read():
#     252             yield self._output()
#     253
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/dviread.py in _read(self)
#     329         while True:
#     330             byte = self.file.read(1)[0]
# --> 331             self._dtable[byte](self, byte)
#     332             downs += self._dtable[byte].__name__ == "_down"
#     333             if (self._baseline_v is None
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/dviread.py in wrapper(self, byte)
#     172             if state is not None and self.state != state:
#     173                 raise ValueError("state precondition failed")
# --> 174             return method(self, *[f(self, byte-min) for f in get_args])
#     175         if max is None:
#     176             table[min] = wrapper
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/dviread.py in _fnt_def(self, k, c, s, d, a, l)
#     474     @_dispatch(min=243, max=246, args=('olen1', 'u4', 'u4', 'u4', 'u1', 'u1'))
#     475     def _fnt_def(self, k, c, s, d, a, l):
# --> 476         self._fnt_def_real(k, c, s, d, a, l)
#     477
#     478     def _fnt_def_real(self, k, c, s, d, a, l):
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/dviread.py in _fnt_def_real(self, k, c, s, d, a, l)
#     481         tfm = _tfmfile(fontname)
#     482         if tfm is None:
# --> 483             raise FileNotFoundError("missing font metrics file: %s" % fontname)
#     484         if c != 0 and tfm.checksum != 0 and c != tfm.checksum:
#     485             raise ValueError('tfm checksum mismatch: %s' % n)
#
# FileNotFoundError: missing font metrics file: phvr7t
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2228                        else suppress())
#    2229                 with ctx:
# -> 2230                     self.figure.draw(renderer)
#    2231
#    2232             if bbox_inches:
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2779             self.patch.draw(renderer)
#    2780             mimage._draw_list_compositing_images(
# -> 2781                 renderer, self, artists, self.suppressComposite)
#    2782
#    2783             for sfig in self.subfigs:
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2919             renderer.stop_rasterizing()
#    2920
# -> 2921         mimage._draw_list_compositing_images(renderer, self, artists)
#    2922
#    2923         renderer.close_group('axes')
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1136         ticks_to_draw = self._update_ticks()
#    1137         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
# -> 1138                                                                 renderer)
#    1139
#    1140         for tick in ticks_to_draw:
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1062         """Return lists of bboxes for ticks' label1's and label2's."""
#    1063         return ([tick.label1.get_window_extent(renderer)
# -> 1064                  for tick in ticks if tick.label1.get_visible()],
#    1065                 [tick.label2.get_window_extent(renderer)
#    1066                  for tick in ticks if tick.label2.get_visible()])
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/axis.py in <listcomp>(.0)
#    1062         """Return lists of bboxes for ticks' label1's and label2's."""
#    1063         return ([tick.label1.get_window_extent(renderer)
# -> 1064                  for tick in ticks if tick.label1.get_visible()],
#    1065                 [tick.label2.get_window_extent(renderer)
#    1066                  for tick in ticks if tick.label2.get_visible()])
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     901
#     902         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 903             bbox, info, descent = self._get_layout(self._renderer)
#     904             x, y = self.get_unitless_position()
#     905             x, y = self.get_transform().transform((x, y))
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     306         _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     307             "lp", self._fontproperties,
# --> 308             ismath="TeX" if self.get_usetex() else False)
#     309         min_dy = (lp_h - lp_d) * self._linespacing
#     310
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     228             fontsize = prop.get_size_in_points()
#     229             w, h, d = texmanager.get_text_width_height_descent(
# --> 230                 s, fontsize, renderer=self)
#     231             return w, h, d
#     232
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     399             dvifile = self.make_dvi(tex, fontsize)
#     400             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
# --> 401                 page, = dvi
#     402             # A total height (including the descent) needs to be returned.
#     403             return page.width, page.height + page.descent, page.descent
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/dviread.py in __iter__(self)
#     249             integers.
#     250         """
# --> 251         while self._read():
#     252             yield self._output()
#     253
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/dviread.py in _read(self)
#     329         while True:
#     330             byte = self.file.read(1)[0]
# --> 331             self._dtable[byte](self, byte)
#     332             downs += self._dtable[byte].__name__ == "_down"
#     333             if (self._baseline_v is None
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/dviread.py in wrapper(self, byte)
#     172             if state is not None and self.state != state:
#     173                 raise ValueError("state precondition failed")
# --> 174             return method(self, *[f(self, byte-min) for f in get_args])
#     175         if max is None:
#     176             table[min] = wrapper
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/dviread.py in _fnt_def(self, k, c, s, d, a, l)
#     474     @_dispatch(min=243, max=246, args=('olen1', 'u4', 'u4', 'u4', 'u1', 'u1'))
#     475     def _fnt_def(self, k, c, s, d, a, l):
# --> 476         self._fnt_def_real(k, c, s, d, a, l)
#     477
#     478     def _fnt_def_real(self, k, c, s, d, a, l):
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/dviread.py in _fnt_def_real(self, k, c, s, d, a, l)
#     481         tfm = _tfmfile(fontname)
#     482         if tfm is None:
# --> 483             raise FileNotFoundError("missing font metrics file: %s" % fontname)
#     484         if c != 0 and tfm.checksum != 0 and c != tfm.checksum:
#     485             raise ValueError('tfm checksum mismatch: %s' % n)
#
# FileNotFoundError: missing font metrics file: phvr7t
